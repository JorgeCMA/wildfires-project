# %% [markdown]
# APRENDIZAJE NO SUPERVISADO, CLUSTERS Y DEMÁS -> GONZALO

# %% [markdown]
# # 03 — Analysis
#
# ## [ENG] Objectives
#
# Statistical analysis and feature engineering on the enriched dataset:
#
# - Fire detection distributions (by month, sensor, confidence)
# - Land cover class breakdown
# - Weather variable correlations with fire activity
# - Geographic patterns
# - Feature engineering for the ML model
#
# ### [ENG] Reminder: explore these indices
#
# - VPD (vapor pressure deficit)
# - Drought index
# - Fire weather index
#
# ## [ESP] Objetivos
#
# Análisis estadístico e ingeniería de características en el dataset enriquecido:
#
# - Distribuciones de detecciones de fuego (por mes, sensor, confianza)
# - Desglose de clases de cobertura del suelo
# - Correlaciones entre variables climáticas y actividad de fuego
# - Patrones geográficos
# - Ingeniería de características para el modelo ML
#
# ### [ESP] Recordatorio: explorar estos índices
#
# - VPD (déficit de presión de vapor)
# - Índice de sequía
# - Índice de clima para incendios
